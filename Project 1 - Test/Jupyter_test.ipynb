# %%
import pandas as pd
s=pd.Series(["Gaurav", "Test1", "Test2"])
s
# Out:
# 0    Gaurav
# 1     Test1
# 2     Test2
# dtype: object

# %%
import pandas as pd

a = ["a", "b", "c"]
b = [10, 20, 30]
s1 = pd.Series(a)
s2 = pd.Series(b)
df=pd.concat([s1,s2], axis=1)
print(df)
# Out:
#    0   1
# 0  a  10
# 1  b  20
# 2  c  30

# %%
import pandas as pd
data={
    "customer_name": ["Shyam", "Ram", "Sita"],
    "Address":["add1", "Add2", "Add3"],
    "Age":[23423423, 343434, 235345345],
    "Gender": ["m", "m", "f"]
}
df=pd.DataFrame(data)
df
# Out:
#   customer_name Address        Age Gender
# 0         Shyam    add1   23423423      m
# 1           Ram    Add2     343434      m
# 2          Sita    Add3  235345345      f

# %%
import pandas as pd
data = {
    "name": ["Shyam", "Ram", "Sita"],
    "address": ["Shyam1", "Ram1", "Sita1"],
    "phone": ["Shyam2", "Ram2", "Sita2"],
}

df=pd.DataFrame(data)
df
# Out:
#     name address   phone
# 0  Shyam  Shyam1  Shyam2
# 1    Ram    Ram1    Ram2
# 2   Sita   Sita1   Sita2

# %%
pip insta
